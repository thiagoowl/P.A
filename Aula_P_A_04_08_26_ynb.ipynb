# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagoowl/P.A/blob/main/Aula_P_A_04_08_26_ynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Crie as variáveis abaixo e mostre o valor e o tipo de cada uma usando print() e type():
#• nome
#• idade
#• altura
#• nota
#• cidade


Nome = str(input("Digite seu nome:"))
Idade = int(input("Digite sua Idade:"))
Altura = float(input("Digite sua altura:"))
Nota = float(input("Digite sua nota:"))
Cidade = str(input("Digite sua cidade:"))


print(type(Nome))
print(type(Idade))
print(type(Altura))
print(type(Nota))
print(type(Cidade))
# Out:
# Digite seu nome:Thiago
# Digite sua Idade:16
# Digite sua altura:1.69
# Digite sua nota:9.2
# Digite sua cidade:Maua
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'str'>

# %%
#Exercício 2 – Contas básicas
#Escreva um programa que:
#• Guarde as notas 7.5, 8.0 e 6.5
#• Calcule a média
#• Mostre a média na tela

nota1 = 7.5
nota2 = 8.0
nota3 = 6.5

media = (nota1 + nota2 + nota3) / 3

print(" a média das notas é", media)
# Out:
#  a média das notas é 7.333333333333333

# %%
from IPython.core.prefilter import PythonOpsChecker
#Exercício 3 – Conversões
#Faça as conversões e mostre o resultado:
#Python
#texto1 = "20"
#texto2 = "3.5"
#numero = 8
#a) Transforme texto1 em inteiro e some com 10 b) Transforme texto2 em real e
#multiplique por 2 c) Transforme número em texto e junte com a palavra "anos"

texto1 = "20"
texto1 = int(texto1)

texto2 = "3.5"
texto2 = float(texto2)

numero = 8
numero = str(numero)

print("A- resultado:",texto1 + 10)
print ("B- resultado:",texto2 * 2)

print("C- resultado:", numero + "anos" )
# Out:
# A- resultado: 30
# B- resultado: 7.0
# C- resultado: 8anos
