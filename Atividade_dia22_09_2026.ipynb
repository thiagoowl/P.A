# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagoowl/P.A/blob/main/Atividade_dia22_09_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercícios
#DICIONÁRIOS
Aluno ={"Thiago", 16, "Informática"}

print(Aluno)
# Out:
# {'Thiago', 16, 'Informática'}

# %%
Aluno ={"Aquiles", 16, "Informática"}
print(Aluno[0])
print(Aluno[1])
print(Aluno[2])
# Out:
# Aquiles
# 16
# Informática

# %%
Produto = {"Nome": "Computador", "Preço": 1600, "Estoque": 50 }

Produto["Preço"] = 2000

print(Produto)
# Out:
# {'Nome': 'Computador', 'Preço': 2000, 'Estoque': 50}

# %%
Aluno ={"Herique", 16}
Aluno.add("Informática")
print(Aluno)
# Out:
# {'Herique', 16, 'Informática'}

# %%
Filme ={"Titulo": "Five Nights At Freddy's 2", "Ano": 2026, "Genero": "Terror", "Nota": 10}

print(Filme["Titulo"])
print(Filme["Ano"])
print(Filme["Genero"])
print(Filme["Nota"])
# Out:
# Five Nights At Freddy's 2
# 2026
# Terror
# 10

# %%
#Exercícios
#Conjunto
Alunos = {"Nome": "Isabelly",
"Idade": 15,
"curso": "Informática"}
print(Alunos)
# Out:
# {'Nome': 'Isabelly', 'Idade': 15, 'curso': 'Informática'}

# %%
numeros = {1, 2, 2 , 3, 3, 4}
print(numeros)
# Out:
# {1, 2, 3, 4}

# %%
Frutas={"Maça", "Banana", "Laranja"}
Frutas.add("Morango")
print(Frutas)
# Out:
# {'Maça', 'Laranja', 'Morango', 'Banana'}

# %%
Cores ={"Vermelho", "Azul", "Verde", "Amarelo"}
Cores.remove("Verde")
print(Cores)
# Out:
# {'Vermelho', 'Azul', 'Amarelo'}

# %%
Nomes= {"Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi", "Gael", "Theo", "Theo"}
Nomes_conjunto= set (Nomes)
print(Nomes_conjunto)
# Out:
# {'Maitê', 'Yris', 'Luna', 'Theo', 'Ravi', 'Gael'}
