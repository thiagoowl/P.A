# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagoowl/P.A/blob/main/AulaPA11_08_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exercício 4 – Expressões aritméticas
# Calcule e mostre o resultado de:
# • O dobro de 15
# • A metade de 90
# • O resto da divisão de 17 por 5
# • 2 elevados à potência 4
# • A média de 10, 8 e 6

dobro = 15 * 2
metade = 90 / 2
resto = 17 % 5
elevado = 2 **4
media = 10 + 8 +6 /3

print("O dobro de 15 é: ",dobro)
print("A metade de 90 é: ",metade)
print("O Resto de 17/5 é: ",resto)
print("O numero 2 elevado a 4 potência é: ",elevado)
print("A média de 10, 8 e 6 é: ",media)
# Out:
# O dobro de 15 é:  30
# A metade de 90 é:  45.0
# O Resto de 17/5 é:  2
# O numero 2 elevado a 4 potência é:  16
# A média de 10, 8 e 6 é:  20.0

# %%
# Exercício 5 – Comparações (relacionais)
# Mostre o resultado (True ou False) das comparações:
# Python
idade = 16
nota = 8.5
preco = 45.0
idade >= 18
nota > 7
preco <= 50
idade == 16
nota != 10

print("idade >= 18")
print("nota > 7")
print("preco <= 50")
print("-------------------------------------------------------------------------------------------------")
print(f"idade >= 18 {idade >= 18}")
print(f"nota > 7 {nota > 7}")
print(f"preco <= 50 {preco <= 50}")
print(f"idade == 16 {idade == 16}")
print(f"nota != 10 {nota != 10}")
# Out:
# idade >= 18
# nota > 7
# preco <= 50
# -------------------------------------------------------------------------------------------------
# idade >= 18 False
# nota > 7 True
# preco <= 50 True
# idade == 16 True
# nota != 10 True

# %%
# Exercício 6 – Situação prática
# Um produto custa R$ 80,00. O cliente ganhou 10% de desconto.
# Faça um programa que calcule e mostre:
# • O valor do desconto
# • O valor final a pagar
# • Se o valor final é menor que 75.00 (True ou False)
finalle = 75
valor = 80
desconto = 80 / 10
resultado = desconto - valor
print("O valor do desconto é igual a:", desconto)
print("O valor final a pagar é igual a:", resultado)
print(f"finalle <= 75 {finalle <= 75}")
# Out:
# O valor do desconto é igual a: 8.0
# O valor final a pagar é igual a: -72.0
# finalle <= 75 True

# %%
# Exercício 7 – Desafio simples
# Crie um programa que:
# • Guarde o nome de um aluno
# • Guarde duas notas
# • Calcule a média
# • Mostre uma frase assim: O aluno João tirou média 7.

aluno = str (input("Digite seu nome:"))
nota1 = float (input("Digite sua 1 nota:" ))
nota2 = float (input("Digite sua 2 nota:" ))

media = (nota1 + nota2) /2

print("O aluno tirou média ",media)
# Out:
# Digite seu nome: Mellzzita
# Digite sua 1 nota: 9
# Digite sua 2 nota: 8
# O aluno tirou média  8.5

# %%
# Exercício 1 – Idade para dirigir
# Receba a idade de uma pessoa e diga se ela pode tirar carteira de motorista. A pessoa
# pode tirar a carteira se tiver idade maior ou igual a 18 anos.

idade = int (input("Digite sua idade:"))

if idade >= 18:
  print("você pode tirar sua habilitação de motorista")
else:
  print("você infelizmente não pode tirar sua habilitação de motorista")
# Out:
# Digite sua idade:16
# você infelizmente não pode tirar sua habilitação de motorista

# %%
# Exercício 2 – Par ou Ímpar
# Receba um número e diga se ele é par ou ímpar.

numero = int (input("Digite um numero:"))

if numero % 2 ==0:
  print("Este numero é um numero par!!")
else:
  print("Este numero é impar")
# Out:
# Digite um numero:688
# Este numero é um numero par!!

# %%
# Exercício 3 – Maior de dois números
# Receba dois números e mostre qual é o maior. Se os dois números forem iguais, diga que
# eles são iguais.

numero1= float (input("Digite um numero:"))
numero2= float (input("Digite um numero:"))

if numero1 > numero2:
  print("numero um é maior que numero dois")
else:
  print("numero um é menor que o numero dois")
# Out:
# Digite um numero:9
# Digite um numero:0.5
# numero um é maior que numero dois

# %%
# Exercício 4 – Situação do aluno
# Receba a nota de um aluno e mostre sua situação:
# Nota maior ou igual a 7 → Aprovado
# Nota maior ou igual a 5 e menor que 7 → Recuperação
# Nota menor que 5 → Reprovado

nota = float (input("digite sua nota:" ))

if nota >= 7:
  print("Você foi aprovado!!")
elif nota >= 5:
  print("Você está de recuperação!!")
else:
  print("Você foi reprovado!!")
# Out:
# digite sua nota:9
# Você foi aprovado!!

# %%
# Exercício 5 – Desconto na compra
# Receba o valor de uma compra. Se o valor for maior ou igual a 100, aplique 10% de
# desconto e mostre o valor final. Caso contrário, mostre o valor normal da compra.

compra = float (input("Digite o valor da sua compra:"))
if compra >= 100:
  porcentagem = compra * 0.1
  valorfinal = compra - porcentagem
  print("o valor final da compra é", {valorfinal})
else:
  print("o valor da compra é", {compra})
# Out:
# Digite o valor da sua compra:350
# o valor final da compra é {315.0}

# %%
# Exercício 6 – Positivo, Negativo ou Zero
# Receba um número e diga se ele é positivo, negativo ou zero.

NUMERO = float (input("Digite seu numero:"))

if NUMERO >= 1:
  print("Este numero é positivo!!")
elif NUMERO <= -1:
  print("Este numero é negativo!!")
else:
  print("este numero é zero")
# Out:
# Digite seu numero:-10
# Este numero é negativo!!

# %%
# Exercício 7 – Classificação de idade
# Receba a idade de uma pessoa e classifique-a de acordo com sua faixa etária:
# Menor de 12 anos → Criança
# De 12 a 17 anos → Adolescente
# De 18 a 59 anos → Adulto
# 60 anos ou mais → Idoso
idade = int(input("digite sua idade: "))
if idade < 12:
  print("você é uma criança")
elif idade >= 12 and idade <= 17:
  print("você é um adolescente")
elif idade >= 18 and idade <= 59:
  print("você é um adulto")
else:
  print("você é um idoso")
# Out:
# digite sua idade: 60
# você é um idoso

# %%
# Exercício 8 – Média de duas notas
# Receba duas notas, calcule a média e diga se o aluno foi aprovado ou reprovado. O aluno
# será aprovado se a média for maior ou igual a 7.
nota1 = float(input("digite a primeira nota: "))
nota2 = float(input("digite a segunda nota: "))
media = (nota1 + nota2) / 2
if media >= 7:
  print(f"você foi aprovado, sua média foi {media}")
else:
  print(f"você foi reprovado, sua média foi {media}")
# Out:
# digite a primeira nota: 0
# digite a segunda nota: 3
# você foi reprovado, sua média foi 1.5

# %%
# Exercício 9 – Login simples
# Receba um usuário e uma senha. Se o usuário for "admin" e a senha for "1234", mostre
# "Login realizado com sucesso". Caso contrário, mostre "Usuário ou senha incorretos".
usuario = str(input("digite o usuário: "))
senha = str(input("digite a senha: "))
if usuario == "admin" and senha == "1234":
  print("login realizado com sucesso")
else:
  print("usuário ou senha incorretos")
# Out:
# digite o usuário: admin
# digite a senha: 1234
# login realizado com sucesso

# %%
# Exercício 10 – Calculadora de IMC
# Receba o peso e a altura de uma pessoa, calcule o IMC usando a fórmula:
# IMC = peso / (altura × altura)
# Depois, classifique o resultado:
# IMC menor que 18.5 → Abaixo do peso
# IMC de 18.5 a 24.9 → Peso normal
# IMC de 25 a 29.9 → Sobrepeso
# IMC maior ou igual a 30 → Obesidad
peso = float(input("digite seu peso: "))
altura = float(input("digite sua altura: "))
imc = peso / (altura * altura)
if imc <= 18.5:
  print (f"seu imc é {imc},o peso está abaixo do normal🙄🙄")
elif imc <= 18.5 and imc >= 24.9:
  print (f"seu imc é {imc},o peso está normal💖💖")
elif imc <= 25 and imc >= 29.9:
  print (f"seu imc é {imc} peso está acima do normal✔✔")
elif imc >= 30:
  print (f"seu imc é {imc}, você está obeso ✨✨")
# Out:
# digite seu peso: 1000
# digite sua altura: 1.90
# seu imc é 277.0083102493075, você está obeso ✨✨
