# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagoowl/P.A/blob/main/Aula_PA_1E_11_03_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Calcular area do retangulo

# Entrada
comprimento = float (input("Digite o valor do comprimento: "))
altura = float (input("Digite o valor da altura: "))

# Processamento

area= comprimento * altura

# Saida
print(f"a area do retangulo é igual: {area} ")
# Out:
# Digite o valor do comprimento: 45
# Digite o valor da altura: 26
# a area do retangulo é igual: 1170.0

# %%
# Escreva um programa que calcula o dobro de um numero

# Entrada
numero = int (input("digite um numero "))
# Processamento
dobro = numero * 2
# Saída
print(f"O dobro de {numero} é igual a: {dobro}")
# Out:
# digite um numero 70
# O dobro de 70 é igual a: 140

# %%
# Escrever um cadastro de um usuário
# Entrada : nome e idade
# Processamento : armazenar os dados do usuário
# Saída : mostrar uma mensagem de boas vindas e o nome e a idade do usuário

# Entrada
nome = str (input("Digite seu nome"))
idade = int (input("Digite sua idade"))
# Processamento
# Saida
print (f"Olá {nome} seja muito bem vindo!")
print (f"você tem {idade} anos")
# Out:
# Digite seu nomeThi Thi
# Digite sua idade16
# Olá Thi Thi seja muito bem vindo!
# você tem 16 anos

# %%
 #Adição +
 #Subtração -
 #Multiplicação *
 #Divisão /

# %%
# Escrever um algoritmo que calcula o triplo de um numero

# Entrada

numero = int (input("digite um nuemro"))

#  Processamento
triplo = numero * 3
# Saída
print(f"O triplo de {numero} é igual a: {triplo}")
# Out:
# digite um nuemro80
# O triplo de 80 é igual a: 240

# %%
# Escrever um programa que receba o nome do usuário e a idade e mostre uma mensagem com o ano de nascimento.
# Entrada : nome e idade e ano de nascimento
# Processamento : armazenar os dados do usuário
# Saída : mostrar uma mensagem de boas vindas e o nome  a idade do usuárioe a ano de nascimento

# Entrada
nome = str (input("Digite seu nome"))
idade = int (input("Digite sua idade"))
ano_atual = int (input("digite o ano atual"))
# Processamento
ano_de_nascimento= ano_atual - idade
# Saida
print (f"O seu ano de nascimento é igual a: {ano_de_nascimento}")
# Out:
# Digite seu nome Thiago
# Digite sua idade 16
# digite o ano atual 2026
# O seu ano de nascimento é igual a: 2010

# %%
# Escrever um programa que faz a converção de temperatura

# Entrada = temperatura em celsius
# Processamento = converter para fahrenheit
# Saída = resultado
# Entrada
celsius = int (input("digite um numero"))

# Processamneto
fahrenheit = (celsius * 9/5) + 32

# Saída
print (f"o valor em fahrenheit é igual a: {fahrenheit}")
# Out:
# digite um numero 21
# o valor em fahrenheit é igual a: 69.8
