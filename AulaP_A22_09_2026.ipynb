# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagoowl/P.A/blob/main/AulaP_A22_09_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Alunos = {"Nome": "Ana",
"Idade": 17,
"curso": "Informática"
}
Alunos["cidade"] = "Mauá"
print(Alunos)
# Out:
# {'Nome': 'Ana', 'Idade': 17, 'curso': 'Informática', 'cidade': 'Mauá'}

# %%
#Lista Exercicios
numeros = {1, 2, 2 , 3, 3, 4}
numeros.remove(3)
print(numeros)
# Out:
# {1, 2, 4}

# %%
Frutos = ["maçã", "Banana", "Laranja", "Morango"]
print(Frutos)
# Out:
# ['maçã', 'Banana', 'Laranja', 'Morango']

# %%
Alunos = ["Rebeca", "Guilherme", "Melissa", "Kyara"]
Alunos.remove("Melissa")
print(Alunos)
# Out:
# ['Rebeca', 'Guilherme', 'Kyara']

# %%
Cores = ["Vermelho", "Azul", "Verde"]
Cores[1] = "Amarelo"
print(Cores)
# Out:
# ['Vermelho', 'Amarelo', 'Verde']

# %%
Alunos = ["Nicolas", "Wendel", "Pyetra"]
Alunos.append("Petros")
print(Alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
Animais=["Cachorro", "Gato", "Coelho", "Passarinho"]
Animais.remove("Coelho")
print(Animais)
# Out:
# ['Cachorro', 'Gato', 'Passarinho']

# %%
#Tupla Exercicios
Meses =("Janeiro", "Fevereiro", "Março", "Abril")
print(Meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %%
Numeros =(10, 20, 30, 40, 50)
print(Numeros[0])
print(Numeros[2])
print(Numeros[4])
# Out:
# 10
# 30
# 50

# %%
Aluno =("Thiago", 16, "Informática")
print(Aluno[0])
print(Aluno[1])
print(Aluno[2])
# Out:
# Thiago
# 16
# Informática

# %%
Cores= ("Vermelho", "Azul", "Verde")

Cores[1]="Amarelo"

print(Cores)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_756/2853411074.py in <cell line: 0>()
#       1 Cores= ("Vermelho", "Azul", "Verde")
#       2
# ----> 3 Cores[1]="Amarelo"
#       4
#       5 print(Cores)
#
# TypeError: 'tuple' object does not support item assignment

# %%
Numeros=(2, 4, 2, 6, 2, 8, 10)
Numeros.count(2)
# Out:
# 3
