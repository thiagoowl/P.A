# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagoowl/P.A/blob/main/CalculoAula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# aula de programação e algoritmos
# - calcule a area
#
# #Entrada
# - Ler Lado1
# - Ler Lado2
#
# #Processamento
# -àrea= lado1 * lado2
#
# #Saida
# imprimir área

# %%
# Calculo de ára

#Entrada

lado1 = 5
lado2 = 4

nome= "ThiThi"

# %%
print (nome)
# Out:
# ThiThi

# %%
#Processamento

área = lado1 * lado2

# %%
#Saida

print (f"Total da área: {área}")
# Out:
# Total da área: 20

# %% [markdown]
# python
#
# #Tipos Numéricos
# idade = 18 # int
# altura = 1.69 # float
# numero_complexo = 4 + 6j # complex
#
# #Tipo texto
# nome = "Evellyng" # str
#
# #Tipo Booleano
# está_chovendo = False #boot

# %%
#Tipos Numéricos
idade = 18 # int
altura = 1.69 # float
numero_complexo = 4 + 6j # complex

#Tipo texto
nome = "Evellyng" # str

#Tipo Booleano
está_chovendo = False #boot
